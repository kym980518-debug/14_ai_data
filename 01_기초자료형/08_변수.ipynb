# %%
# 변수는 어떻게 만들까?
# 변수이름 = 변수에 저장할 값

# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_) 사용할 수 있다.
# 2. 숫자로는 시작할 수 없다.
# 3. 예약어(명령어)는 사용할 수 없다.(print, del 등 내장함수 사용 불가)
# 4. 대소문자 구분 한다.

name = "홍길동"
# 1name = "유재석"
name2 = "강호동"

# user-name = "홍길동"
user_name = "홍길동"

# 컨벤션
# user_name = (0) 스네이크 스타일
# userName = (0) 카멜 스타일
# UserName = (0) 파스칼

# %%
a = [1, 2, 3]
print(id(a))
b = [1, 2, 3]
print(id(b))

a.append(4)
print(a)
print(id(a))
# Out:
# 2183943113536
# 2183943023296
# [1, 2, 3, 4]
# 2183943113536

# %%
b = a
print(id(b))
# Out:
# 2183943113536

# %%
a = [1, 2, 3]
b = a[:]
print(b)
print(id(a))
print(id(b))
# Out:
# [1, 2, 3]
# 2183943734272
# 2183941510976

# %%
# 변수를 만드는 여러가지 방법

a, b = ["python", "like"]
print(a)
print(b)
print(type(a))
# Out:
# python
# like
# <class 'str'>

# %%
(a, b) = ("python", "like")
print(a)
print(b)
print(type(a))
# Out:
# python
# like
# <class 'str'>

# %%
a = b = "python"
print(a)
print(b)
print(type(a))
# Out:
# python
# python
# <class 'str'>

# %%
a = 3
b = 5

a, b = b, a
print(a)
print(b)
# Out:
# 5
# 3
